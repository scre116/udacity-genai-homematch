# %% [markdown]
# # HomeMatch
#
# HomeMatch is a property recommendation system that helps users find their ideal home based on their preferences and requirements. The system uses a combination of language models and vector embeddings to match user-defined criteria with real estate listings. It ranks the listings based on relevance to the user's preferences and generates personalized descriptions for the top matches.

# %%
# Initialization

import re
from typing import List

from dotenv import load_dotenv
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.tools import tool
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from pydantic import BaseModel

load_dotenv(override=True)

vocareum_url = "https://openai.vocareum.com/v1"
llm = ChatOpenAI(
    model="gpt-4o-mini",
    base_url=vocareum_url,
)

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
    base_url=vocareum_url,
)

listings_path = "Listings.txt"
db_path = "chroma_db"

# %% [markdown]
# ## Prepare listings
#
# Listings are loaded from the text file and prepared for embedding. Relevant keywords are extracted from the description and neighborhood description using LLM. This will be used for the similarity search.

# %%
class Listing(BaseModel):
    listing_number: int
    neighborhood: str
    price: str
    bedrooms: int
    bathrooms: float
    house_size: str
    description: str
    neighborhood_description: str
    description_keywords: str
    neighborhood_keywords: str
    score: float = None

# %%
def parse_listings(file_content: str) -> List[Listing]:
    """Parse the content of the listings file and construct a list of Listing objects. Keywords are generated using LLM."""
    # Split the content into individual listings
    raw_listings = file_content.split("\n\n")

    listings = []
    for raw_listing in raw_listings:
        # Extract information using regex
        listing_number = int(re.search(r"Listing (\d+)", raw_listing).group(1))
        neighborhood = re.search(r"Neighborhood: (.+)", raw_listing).group(1)
        price = re.search(r"Price: (.+)", raw_listing).group(1)
        bedrooms = int(re.search(r"Bedrooms: (\d+)", raw_listing).group(1))
        bathrooms = float(re.search(r"Bathrooms: ([\d.]+)", raw_listing).group(1))
        house_size = re.search(r"House Size: (.+)", raw_listing).group(1)
        description = re.search(r"Description: (.+)", raw_listing).group(1).strip()
        neighborhood_description = re.search(r"Neighborhood Description: (.+)", raw_listing).group(1).strip()

        description_keywords = extract_keywords(
            "Generate a comma-separated list of search keywords that a potential buyer might use to find this property, based on its description:\n{description}",
            description)
        neighborhood_keywords = extract_keywords(
            "Generate a comma-separated list of search keywords that would help someone find this type of neighborhood, based on the following description:\n{description}",
            neighborhood_description)

        listing = Listing(
            listing_number=listing_number,
            neighborhood=neighborhood,
            price=price,
            bedrooms=bedrooms,
            bathrooms=bathrooms,
            house_size=house_size,
            description=description,
            neighborhood_description=neighborhood_description,
            description_keywords=description_keywords,
            neighborhood_keywords=neighborhood_keywords,
        )
        listings.append(listing)

    return listings


def extract_keywords(prompt, description) -> str:
    """Extract keywords from the description using LLM."""
    prompt = PromptTemplate.from_template(prompt + ": {description}")
    chain = prompt | llm | StrOutputParser()
    summary = chain.invoke({"description": description})
    return summary


def load_listings(file_path: str) -> List[Listing]:
    """Load the listings from the specified file and return a list of Listing objects."""
    with open(file_path, 'r') as file:
        content = file.read()

    listings = parse_listings(content)

    return listings


processed_listings = load_listings(listings_path)
print(f"Loaded {len(processed_listings)} listings.")

# Print one of the listings:
listing = processed_listings[10]
print(f"Listing {listing.listing_number}")
print(f"Neighborhood: {listing.neighborhood}")
print(f"Price: {listing.price}")
print(f"Bedrooms: {listing.bedrooms}")
print(f"Bathrooms: {listing.bathrooms}")
print(f"House Size: {listing.house_size}")
print(f"Description: {listing.description}")
print(f"Description Keywords: {listing.description_keywords}")
print(f"Neighborhood Description: {listing.neighborhood_description}")
print(f"Neighborhood Keywords: {listing.neighborhood_keywords}")
print("\n")
# Out:
# Loaded 13 listings.
# Listing 11
# Neighborhood: Riverside Heights
# Price: $1,250,000
# Bedrooms: 4
# Bathrooms: 3.5
# House Size: 3,200 sqft
# Description: Experience luxury living in this stunning waterfront property in Riverside Heights. This contemporary 4-bedroom, 3.5-bathroom home offers breathtaking views of the river from floor-to-ceiling windows. The gourmet kitchen features top-of-the-line appliances and a large island, perfect for entertaining. Relax in the master suite with a private balcony and spa-like bathroom. The lower level includes a home theater and wine cellar. Step outside to your private dock for easy access to water activities. This modern masterpiece combines elegance with the tranquility of waterfront living.
# Description Keywords: waterfront property, luxury home for sale, Riverside Heights real estate, contemporary house, 4-bedroom home, 3.5-bathroom property, river view house, gourmet kitchen, home theater, wine cellar, private dock, modern luxury living, spa-like master suite, entertaining space, floor-to-ceiling windows, outdoor water activities, elegant home, tranquil waterfront living, private balcony, upscale real estate
# Neighborhood Description: Riverside Heights is an upscale neighborhood known for its scenic beauty and outdoor recreation. Enjoy waterfront dining, boutique shopping, and art galleries along the vibrant River Walk. The area boasts excellent schools and is home to the prestigious Riverside Country Club. With its proximity to downtown and easy highway access, Riverside Heights offers the perfect blend of urban convenience and natural splendor.
# Neighborhood Keywords: Riverside Heights, upscale neighborhoods, scenic beauty, outdoor recreation, waterfront dining, boutique shopping, art galleries, River Walk, excellent schools, Riverside Country Club, downtown proximity, easy highway access, urban convenience, natural splendor, luxury living, family-friendly neighborhoods, recreational activities, vibrant community, scenic waterfront, cultural attractions.

# %% [markdown]
# ## Create Embeddings
#
# Embed the listings in a Chroma vector database. Save locally for future use.

# %%
def get_documents_for_embedding(listings: List[Listing]) -> List[Document]:
    """Convert the listings into documents for embedding. The documents contain only the content that is optimal for the similarity search."""
    documents = []
    for listing in listings:
        text = f"""
        Neighborhood: {listing.neighborhood}
        Price: {listing.price}
        Bedrooms: {listing.bedrooms}
        Bathrooms: {listing.bathrooms}
        House Size: {listing.house_size}
        Description Keywords: {listing.description_keywords}
        Neighborhood Description Keywords: {listing.neighborhood_keywords}
        """
        document = Document(
            page_content=text,
            metadata=listing.model_dump(exclude_none=True, exclude_unset=True),
        )
        documents.append(document)

    return documents


# load db from disk
db = Chroma(persist_directory=db_path, embedding_function=embeddings)
if db._collection.count() == 0:
    print("Database is empty. Adding documents...")

    documents_for_embedding = get_documents_for_embedding(processed_listings)

    db = Chroma.from_documents(
        documents_for_embedding,
        embeddings,
        persist_directory=db_path
    )
    print(f"Database now contains {db._collection.count()} documents.")
else:
    print(f"Database already contains {db._collection.count()} documents.")
# Out:
# Database is empty. Adding documents...
# Database now contains 13 documents.

# %% [markdown]
# ## User Search
#
# User will answer a series of questions to define their property search criteria. The answers will be used to generate an ideal personalized property listing summary. This summary will be used to search for real similar listings in the vector database. The top 5 similar listings will be retrieved and reranked by the LLM based on the user's preferences. The three listings with the largest score will be used to generate personalized descriptions and displayed to the user.

# %%
question_1 = "How big do you want your house to be?"
question_2 = "What are 3 most important things for you in choosing this property?"
question_3 = "Which amenities would you like?"
question_4 = "Which transportation options are important to you?"
question_5 = "How urban do you want your neighborhood to be?"

# %%
# Create an ideal listing based on user's answers

ideal_listing_prompt_template = PromptTemplate.from_template(f"""
Based on the user's answers to the following questions, create a property listing summary in the format provided below. Ensure the document reflects the user's preferences and requirements for their ideal home. The summary should be detailed and cohesive, capturing the user's desired house size, important features, amenities, transportation options, and urban preference.

# Format for the Property Listing Summary:
Neighborhood: [Include only if explicitly specified by the user]
Price: [Estimate a price range based on house size and amenities]
Bedrooms: [Match the number of bedrooms specified by the user]
Bathrooms: [Estimate the number of bathrooms based on house size or user preference]
House Size: [Match the house size specified by the user]
Description Keywords: [Generate a comma-separated list of search keywords based on the user's important features and amenities. Mention the house layout, special features, and overall appeal]
Neighborhood Description Keywords: [Generate a comma-separated list of search keywords based on the user's urban preference, transportation needs, and lifestyle]

# Example User's Answers:
{question_1}
"A comfortable three-bedroom house with a spacious kitchen and a cozy living room."

{question_2}
"A quiet neighborhood, good local schools, and convenient shopping options."

{question_3}
"A backyard for gardening, a two-car garage, and a modern, energy-efficient heating system."

{question_4}
"Easy access to a reliable bus line, proximity to a major highway, and bike-friendly roads."

{question_5}
"A balance between suburban tranquility and access to urban amenities like restaurants and theaters."

# Example Summary:
Price: $750,000
Bedrooms: 3
Bathrooms: 2
House Size: 1,800 sqft
Description Keywords: three-bedroom, spacious kitchen, cozy living room, backyard for gardening, two-car garage, modern heating system, energy-efficient, comfortable home
Neighborhood Description Keywords: quiet neighborhood, good local schools, convenient shopping, suburban tranquility, urban amenities, restaurants, theaters, reliable bus line, major highway, bike-friendly roads

# User's Answers:
{question_1}
"{{user_search_1}}"

{question_2}
"{{user_search_2}}"

{question_3}
"{{user_search_3}}"

{question_4}
"{{user_search_4}}"

{question_5}
"{{user_search_5}}"

Now create the property listing summary based on the user's answers in the format provided above.
""")


def create_ideal_listing(user_search: List[str]) -> str:
    """Create an ideal property listing based on the user's answers to the questions using LLM."""

    chain = ideal_listing_prompt_template | llm | StrOutputParser()
    return chain.invoke({
        "user_search_1": user_search[0],
        "user_search_2": user_search[1],
        "user_search_3": user_search[2],
        "user_search_4": user_search[3],
        "user_search_5": user_search[4],
    })

# %%
# Search for similar listings based on the ideal listing

def search_listings(ideal_listing) -> List[Listing]:
    """Execute a similarity search in the vector database to find listings similar to the ideal listing."""

    retriever = db.as_retriever(
        search_type="similarity",
        search_kwargs={"k": 5},
    )
    documents = retriever.invoke(ideal_listing)
    return [Listing(**doc.metadata) for doc in documents]

# %%
# Rank the listings based on the user's preferences

class LLMRating(BaseModel):
    reasoning: str
    score: float


@tool(return_direct=True)
def create_rating(reasoning: str, score: float) -> LLMRating:
    """Creates a rating based on the reasoning and score provided."""

    return LLMRating(reasoning=reasoning, score=score)


def rate_listing(listing: Listing, user_search) -> Listing:
    """Rate the listing based on the user's preferences and requirements using LLM."""

    listing_text = f"""
    Neighborhood: {listing.neighborhood}
    Price: {listing.price}
    Bedrooms: {listing.bedrooms}
    Bathrooms: {listing.bathrooms}
    House Size: {listing.house_size}
    Description: {listing.description}
    Neighborhood Description: {listing.neighborhood_description}
    """

    rating_template = PromptTemplate.from_template(f"""
    Based on the user's preferences and requirements, rate the following property listing on a scale of 1 to 10, with 10 being the most relevant and 1 being the least relevant. Consider the user's ideal house size, important features, amenities, transportation options, and urban preference.

    # User's Answers:
    {question_1}
    "{user_search[0]}"

    {question_2}
    "{user_search[1]}"

    {question_3}
    "{user_search[2]}"

    {question_4}
    "{user_search[3]}"

    {question_5}
    "{user_search[4]}"

    # Listing:
    {listing_text}
    
    Please provide a detailed reasoning for your rating based on the user's preferences and the listing details. After the reasoning, give a final score on a scale of 1 to 10. Use tool 'create_rating' to transmit the results.
    """)

    llm_with_tools = llm.bind_tools([create_rating], tool_choice="create_rating")

    chain = rating_template | llm_with_tools

    # Invoke the chain and extract the score
    response = chain.invoke({})

    listing.score = response.tool_calls[0]["args"]["score"]

    return listing


def rank_listings(listings: List[Listing], user_search) -> List[Listing]:
    """Rate and rank the listings based on the user's preferences and requirements. The best matches will be at the top."""

    for listing in listings:
        rate_listing(listing, user_search)
    return sorted(listings, key=lambda x: x.score, reverse=True)

# %%
# Generate personalized descriptions

def create_personalized_description(original_listing: Listing, user_search) -> str:
    """Generate a personalized property and neighborhood description based on the user's answers and the original listing."""

    description_template = PromptTemplate.from_template(f"""
    Generate a personalized description for the following property listing.

    # User's Answers:
    {question_1}
    "{user_search[0]}"

    {question_2}
    "{user_search[1]}"

    {question_3}
    "{user_search[2]}"

    {question_4}
    "{user_search[3]}"

    {question_5}
    "{user_search[4]}"

    # Original Listing:
    Neighborhood: {original_listing.neighborhood}
    Price: {original_listing.price}
    Bedrooms: {original_listing.bedrooms}
    Bathrooms: {original_listing.bathrooms}
    House Size: {original_listing.house_size}
    Property Description: {original_listing.description}
    Neighborhood Description: {original_listing.neighborhood_description}
    
    The generated description should subtly highlight the key features and amenities that align with the user's answers. DO NOT INVENT FEATURES THAT DO NOT EXIST IN THE ORIGINAL DESCRIPTION. The output should consist of two parts: the personalized property and neighborhood descriptions.
    """)

    chain = description_template | llm | StrOutputParser()
    return chain.invoke({})

# %%
# Print results

def search_and_print_results(user_answers: List[str]):
    """Search for listings based on the user's answers and print the top 3 matches with personalized descriptions."""

    ideal_listing = create_ideal_listing(user_answers)
    found_listings = search_listings(ideal_listing)
    ranked_listings = rank_listings(found_listings, user_answers)

    print("We selected the top 3 listings that most closely match your preferences:\n\n")
    #iterate with index
    for i, listing in enumerate(ranked_listings[:3]):
        personalized_description = create_personalized_description(listing, [answer_1, answer_2, answer_3, answer_4, answer_5])

        print(f"Listing {i + 1}\n\n",

              f"HomeMatch Score: {listing.score}\n",
              f"Internal listing id: {listing.listing_number}\n\n",

              f"Original Listing:\n",
              f"Neighborhood: {listing.neighborhood}\n",
              f"Price: {listing.price}\n",
              f"Bedrooms: {listing.bedrooms}\n",
              f"Bathrooms: {listing.bathrooms}\n",
              f"House Size: {listing.house_size}\n",
              f"Description: {listing.description}\n",
              f"Neighborhood Description: {listing.neighborhood_description}\n\n",
              
              f"{personalized_description}\n",
              )

# %% [markdown]
# ### Simulate User Search 1

# %%
# "How big do you want your house to be?"
answer_1 = "A spacious four-bedroom house with an open-concept layout and a home office."

# "What are 3 most important things for you in choosing this property?"
answer_2 = "Proximity to nature, a vibrant community with social activities, and a well-maintained property."

# "Which amenities would you like?"
answer_3 = "A swimming pool, a gourmet kitchen, and a home theater."

# "Which transportation options are important to you?"
answer_4 = "Access to a reliable train station, easy highway access, and walkable streets."

# "How urban do you want your neighborhood to be?"
answer_5 = "Suburban, with a quiet atmosphere but within a short drive to urban conveniences like shopping centers and restaurants."

search_and_print_results([answer_1, answer_2, answer_3, answer_4, answer_5])
# Out:
# We selected the top 3 listings that most closely match your preferences:
#
#
# Listing 1
#
#  HomeMatch Score: 10
#  Internal listing id: 1
#
#  Original Listing:
#  Neighborhood: Sunset Valley
#  Price: $1,200,000
#  Bedrooms: 4
#  Bathrooms: 3.0
#  House Size: 3,500 sqft
#  Description: Discover luxury living in this modern 4-bedroom, 3-bathroom home in Sunset Valley. This high-end property features smart home technology, a gourmet kitchen with state-of-the-art appliances, and a spacious home theater. The expansive living area opens up to a large backyard with a swimming pool and an outdoor kitchen, perfect for entertaining. The master suite includes a private balcony with stunning mountain views.
#  Neighborhood Description: Sunset Valley is an upscale community known for its serene mountain views and proximity to Sunset Park. Residents enjoy the area's exclusive shopping and dining options, as well as easy access to hiking trails and top-rated schools.
#
#  **Personalized Property Description:**
#
# Welcome to your dream home in the heart of Sunset Valley! This spacious 4-bedroom, 3-bathroom residence offers an ideal open-concept layout that seamlessly combines elegance and functionality, making it perfect for both relaxation and entertaining. With 3,500 sqft of luxurious living space, this modern property features smart home technology to enhance your lifestyle. The gourmet kitchen is a culinary enthusiast's paradise, equipped with state-of-the-art appliances, perfect for preparing delightful meals. The expansive living area flows effortlessly into a beautifully landscaped backyard, where a sparkling swimming pool awaits—ideal for summer gatherings or quiet evenings under the stars. For movie nights or gaming marathons, retreat to your own private home theater. Additionally, the master suite boasts a private balcony that captures breathtaking mountain views, ensuring a serene escape at the end of the day.
#
# **Personalized Neighborhood Description:**
#
# Nestled in the tranquil enclave of Sunset Valley, this upscale community offers the perfect balance between suburban charm and urban convenience. Just moments away, you'll find the serene Sunset Park, ideal for nature enthusiasts who crave outdoor activities and scenic walks. The vibrant community is alive with social activities and features exclusive shopping and dining options, ensuring you never miss out on local events. Plus, with easy access to a reliable train station and major highways, commuting is a breeze, while walkable streets enhance your neighborhood experience. Enjoy the best of both worlds—peaceful living with the excitement of urban amenities just a short drive away. Welcome home!
#
# Listing 2
#
#  HomeMatch Score: 9
#  Internal listing id: 6
#
#  Original Listing:
#  Neighborhood: Pine Hill
#  Price: $800,000
#  Bedrooms: 4
#  Bathrooms: 3.5
#  House Size: 2,800 sqft
#  Description: Elegant 4-bedroom, 3.5-bathroom Colonial home in Pine Hill. This property features a spacious traditional layout, hardwood floors, and a finished basement with a home theater. The large backyard includes a swimming pool and a play area for kids.
#  Neighborhood Description: Pine Hill is a picturesque, family-friendly neighborhood with tree-lined streets and top-rated schools. Residents enjoy the proximity to Pine Hill Park and the local community center, which offers various activities and programs.
#
#  **Personalized Property Description:**
#
# Welcome to your dream home in the heart of Pine Hill! This elegant 4-bedroom, 3.5-bathroom Colonial is designed for modern living, featuring a spacious open-concept layout that seamlessly connects the living, dining, and gourmet kitchen areas, perfect for entertaining family and friends. With 2,800 sqft of living space, you'll enjoy the luxury of a dedicated home office, ideal for those who work remotely. The finished basement is a true highlight, offering a home theater for movie nights and a cozy retreat. Step outside into your well-maintained backyard oasis, where a refreshing swimming pool awaits, alongside a play area for the little ones to enjoy.
#
# **Personalized Neighborhood Description:**
#
# Nestled in the picturesque Pine Hill neighborhood, this property is perfectly positioned for those who appreciate both tranquility and community. Surrounded by nature, with easy access to Pine Hill Park and scenic walking trails, you’ll find plenty of opportunities to explore the outdoors. The vibrant community atmosphere is enhanced by a local community center, which hosts a variety of social activities and programs for residents. Enjoy the peace of suburban living, while being just a short drive away from urban conveniences such as shopping centers and restaurants. With reliable transportation options including a nearby train station and easy highway access, commuting to work or weekend getaways is a breeze. Experience the perfect blend of comfort, community, and convenience in your new home!
#
# Listing 3
#
#  HomeMatch Score: 9
#  Internal listing id: 11
#
#  Original Listing:
#  Neighborhood: Riverside Heights
#  Price: $1,250,000
#  Bedrooms: 4
#  Bathrooms: 3.5
#  House Size: 3,200 sqft
#  Description: Experience luxury living in this stunning waterfront property in Riverside Heights. This contemporary 4-bedroom, 3.5-bathroom home offers breathtaking views of the river from floor-to-ceiling windows. The gourmet kitchen features top-of-the-line appliances and a large island, perfect for entertaining. Relax in the master suite with a private balcony and spa-like bathroom. The lower level includes a home theater and wine cellar. Step outside to your private dock for easy access to water activities. This modern masterpiece combines elegance with the tranquility of waterfront living.
#  Neighborhood Description: Riverside Heights is an upscale neighborhood known for its scenic beauty and outdoor recreation. Enjoy waterfront dining, boutique shopping, and art galleries along the vibrant River Walk. The area boasts excellent schools and is home to the prestigious Riverside Country Club. With its proximity to downtown and easy highway access, Riverside Heights offers the perfect blend of urban convenience and natural splendor.
#
#  **Personalized Property Description:**
#
# Welcome to your dream home in Riverside Heights, a spacious and contemporary 4-bedroom, 3.5-bathroom retreat that beautifully blends luxury with comfort. Spanning 3,200 sqft, this open-concept layout is perfect for modern living and includes a dedicated home office for your professional needs. The gourmet kitchen is a chef’s paradise, featuring top-of-the-line appliances and a generous island, ideal for entertaining family and friends. Enjoy relaxing evenings in your master suite, complete with a private balcony overlooking the serene river, and unwind in the spa-like bathroom that elevates your everyday routine. The lower level is designed for entertainment, boasting a state-of-the-art home theater and a wine cellar for your collection. Outside, your private dock allows for effortless access to water activities, making this home a haven for nature lovers and leisure seekers alike.
#
# **Personalized Neighborhood Description:**
#
# Riverside Heights is a vibrant suburban community that perfectly balances tranquility with sociable living. Known for its scenic beauty, this neighborhood offers a wealth of outdoor recreational opportunities, from scenic riverside walks to lush parks. The area is alive with local events and social activities, fostering a sense of community among residents. Enjoy waterfront dining and boutique shopping along the picturesque River Walk, or take advantage of the excellent schools and the prestigious Riverside Country Club within the community. With reliable train access and easy highway connections, you’ll find that urban conveniences like shopping centers and restaurants are just a short drive away. Experience the best of both worlds, where the peaceful atmosphere of suburban life meets the excitement of urban amenities.

# %% [markdown]
# ### Simulate User Search 2

# %%
# How big do you want your house to be?
answer_1 = "A cozy two-bedroom condo with a modern design and lots of natural light."

# What are 3 most important things for you in choosing this property?
answer_2 = "Close to public transportation, within walking distance to cafes and shops, and in a safe neighborhood."

# Which amenities would you like?
answer_3 = "A fitness center in the building, a balcony with a view, and high-speed internet."

# Which transportation options are important to you?
answer_4 = "Proximity to a metro station, bike lanes, and ride-sharing services."

# How urban do you want your neighborhood to be?
answer_5 = "Urban, with a bustling city feel and lots of cultural and entertainment options nearby."

search_and_print_results([answer_1, answer_2, answer_3, answer_4, answer_5])
# Out:
# We selected the top 3 listings that most closely match your preferences:
#
#
# Listing 1
#
#  HomeMatch Score: 7
#  Internal listing id: 7
#
#  Original Listing:
#  Neighborhood: Riverstone Ridge
#  Price: $950,000
#  Bedrooms: 3
#  Bathrooms: 2.5
#  House Size: 2,300 sqft
#  Description: Contemporary 3-bedroom, 2.5-bathroom townhouse in Riverstone Ridge. This property offers a sleek design with an open-concept living area, high ceilings, and large windows. The rooftop terrace provides panoramic views of the river and the city.
#  Neighborhood Description: Riverstone Ridge is a trendy, up-and-coming neighborhood with a mix of modern living and natural beauty. Enjoy walking along the river, visiting local boutiques, and dining at hip cafes and restaurants. Excellent public transportation options make commuting easy.
#
#  **Personalized Property Description:**
#
# Welcome to your dream retreat in the heart of Riverstone Ridge! This contemporary townhouse, featuring three spacious bedrooms and 2.5 bathrooms, embodies modern living with a touch of elegance. The open-concept layout is flooded with natural light, thanks to the large windows that offer stunning views of the bustling city. You'll love the sleek design and high ceilings that create an airy ambiance. Enjoy your morning coffee or unwind in the evening on the rooftop terrace, where panoramic views of the river and city skyline await. Although this unit features three bedrooms, it provides ample space for a cozy living experience.
#
# **Personalized Neighborhood Description:**
#
# Riverstone Ridge is the epitome of urban living, combining the vibrancy of city life with the tranquility of nature. Just steps away from your front door, you’ll find an array of cafes and boutiques that make for perfect weekend outings. The neighborhood is well-connected with excellent public transportation options, including a nearby metro station and bike lanes, making commuting a breeze. Enjoy the safety and friendliness of the area, perfect for evening strolls or visiting local events. With a fitness center in the building and the cultural and entertainment hubs just a short walk away, this community offers everything you need for a dynamic and fulfilling lifestyle.
#
# Listing 2
#
#  HomeMatch Score: 6
#  Internal listing id: 3
#
#  Original Listing:
#  Neighborhood: Downtown Heights
#  Price: $900,000
#  Bedrooms: 3
#  Bathrooms: 2.5
#  House Size: 1,800 sqft
#  Description: Modern 3-bedroom, 2.5-bathroom condo in the heart of Downtown Heights. This urban oasis features floor-to-ceiling windows with stunning city skyline views, an open-concept living area, and a sleek, contemporary design. The building offers a rooftop terrace, fitness center, and concierge services.
#  Neighborhood Description: Downtown Heights is a vibrant, bustling district known for its nightlife, dining, and cultural attractions. With easy access to public transportation, residents can enjoy everything the city has to offer, from theaters to museums to trendy cafes.
#
#  **Personalized Property Description:**
#
# Welcome to your future home in the heart of Downtown Heights! This cozy two-bedroom condo, bathed in natural light, offers a modern design that perfectly balances comfort and style. Although it features three bedrooms, you’ll appreciate the versatility that allows for creative use of space—transform an extra bedroom into a stylish home office or a cozy guest room. Floor-to-ceiling windows provide stunning city skyline views, creating a bright and inviting atmosphere. The open-concept living area is ideal for entertaining or simply relaxing after a busy day. Enjoy your morning coffee or unwind in the evenings on your private balcony, while taking in the vibrant urban scenery. The building boasts a fitness center to keep you active, high-speed internet for all your connectivity needs, and a rooftop terrace that elevates your living experience.
#
# **Personalized Neighborhood Description:**
#
# Nestled in the vibrant Downtown Heights, this condo places you in a bustling urban district rich with cultural and entertainment options. Enjoy the ease of public transportation with a metro station just steps away, making your commutes a breeze. Explore the local scene with cafes and shops within walking distance, perfect for leisurely weekend strolls or grabbing a quick bite. The neighborhood is known for its safety, allowing you to enjoy the lively nightlife and dining without worry. With bike lanes and ride-sharing services readily available, you have every option to navigate the city with convenience. Experience the best of urban living in Downtown Heights, where excitement and culture converge right outside your door.
#
# Listing 3
#
#  HomeMatch Score: 5
#  Internal listing id: 12
#
#  Original Listing:
#  Neighborhood: Historic Milltown
#  Price: $450,000
#  Bedrooms: 2
#  Bathrooms: 1.0
#  House Size: 1,100 sqft
#  Description: Step back in time with this charming Victorian cottage in the heart of Historic Milltown. This lovingly restored 2-bedroom, 1-bathroom home features original hardwood floors, intricate woodwork, and a cozy fireplace. The updated kitchen blends modern conveniences with vintage charm. Enjoy your morning coffee on the wrap-around porch or tend to the English garden in the backyard. This quaint home offers the perfect balance of historic character and modern comfort, ideal for those seeking a slice of small-town Americana.
#  Neighborhood Description: Historic Milltown is a picturesque community that takes pride in preserving its rich heritage. Stroll down tree-lined streets adorned with beautifully maintained 19th-century homes. The neighborhood hosts various annual events, including the popular Milltown Heritage Festival. Residents enjoy access to local farmer's markets, antique shops, and the scenic Mill Creek Trail. With its strong sense of community and walkable downtown, Historic Milltown offers a nostalgic small-town lifestyle with all the necessary amenities.
#
#  **Personalized Property Description:**
#
# Discover modern living in this cozy two-bedroom condo, perfectly situated in the vibrant Historic Milltown neighborhood. With 1,100 square feet of thoughtfully designed space, this home boasts an abundance of natural light that illuminates the stylish interiors. The updated kitchen seamlessly blends contemporary convenience with charming vintage elements, while the inviting living area, complete with a cozy fireplace, offers a perfect retreat after a bustling day in the city.
#
# Step out onto your private balcony and soak in the views, ideal for morning coffee or evening relaxation. This condo is located in a building that features a state-of-the-art fitness center, ensuring that your wellness routine is just an elevator ride away. High-speed internet connectivity keeps you connected to the world, making this property a perfect choice for both professionals and urban dwellers alike.
#
# **Personalized Neighborhood Description:**
#
# Experience the dynamic charm of Historic Milltown, a neighborhood that beautifully combines urban excitement with a close-knit community feel. With a bustling city atmosphere, you'll find an array of cafes, shops, and cultural attractions just a short stroll away, perfect for those who appreciate the convenience of vibrant city life. The area is well-connected, with a metro station nearby, bike lanes for eco-friendly commuting, and ample ride-sharing options for ease of travel.
#
# Historic Milltown is not only rich in heritage but also offers a lively calendar of events, including the renowned Milltown Heritage Festival. Explore local farmer's markets, charming antique shops, and the scenic Mill Creek Trail, making it easy to embrace the outdoors. This neighborhood promises a safe, walkable environment where you can enjoy the best of urban living while feeling the warmth of a welcoming community.

# %% [markdown]
# ### Simulate User Search 3

# %%
# How big do you want your house to be?
answer_1 = "A three-bedroom townhouse with a finished basement and plenty of storage space."

# What are 3 most important things for you in choosing this property?
answer_2 = "A family-friendly neighborhood, close to good schools, and a sense of community."

# Which amenities would you like?
answer_3 = "A playground for kids, a two-car garage, and energy-efficient appliances."

# Which transportation options are important to you?
answer_4 = "Access to a bus route, proximity to major highways, and carpooling options."

# How urban do you want your neighborhood to be?
answer_5 = "Suburban, with a mix of tranquility and convenient access to essential services and family-oriented amenities."

search_and_print_results([answer_1, answer_2, answer_3, answer_4, answer_5])
# Out:
# We selected the top 3 listings that most closely match your preferences:
#
#
# Listing 1
#
#  HomeMatch Score: 8
#  Internal listing id: 6
#
#  Original Listing:
#  Neighborhood: Pine Hill
#  Price: $800,000
#  Bedrooms: 4
#  Bathrooms: 3.5
#  House Size: 2,800 sqft
#  Description: Elegant 4-bedroom, 3.5-bathroom Colonial home in Pine Hill. This property features a spacious traditional layout, hardwood floors, and a finished basement with a home theater. The large backyard includes a swimming pool and a play area for kids.
#  Neighborhood Description: Pine Hill is a picturesque, family-friendly neighborhood with tree-lined streets and top-rated schools. Residents enjoy the proximity to Pine Hill Park and the local community center, which offers various activities and programs.
#
#  **Personalized Property Description:**
#
# Welcome to your dream home in Pine Hill! This elegant 4-bedroom, 3.5-bathroom Colonial residence offers a spacious 2,800 sqft layout, perfect for families seeking both comfort and style. The finished basement is ideal for family movie nights or as a play area, providing ample storage space for all your needs. Step outside to enjoy the large backyard, where you’ll find a swimming pool and a dedicated play area, perfect for creating memorable moments with your children. With energy-efficient appliances throughout and a convenient two-car garage, this home combines modern convenience with a warm, inviting atmosphere.
#
# **Personalized Neighborhood Description:**
#
# Nestled in the picturesque neighborhood of Pine Hill, this property is situated in a family-friendly community known for its tree-lined streets and a strong sense of camaraderie among residents. With top-rated schools just a stone's throw away and the nearby Pine Hill Park, your family will have access to endless recreational activities. The local community center offers various programs tailored for all ages, fostering a vibrant neighborhood spirit. Enjoy the tranquility of suburban living while being conveniently close to bus routes, major highways, and carpooling options, ensuring that essential services and family-oriented amenities are always within reach. Pine Hill is not just a place to live; it's a place to thrive!
#
# Listing 2
#
#  HomeMatch Score: 7
#  Internal listing id: 5
#
#  Original Listing:
#  Neighborhood: Green Meadows
#  Price: $450,000
#  Bedrooms: 3
#  Bathrooms: 2.0
#  House Size: 1,600 sqft
#  Description: Cozy 3-bedroom, 2-bathroom ranch-style home in Green Meadows. Recently renovated with modern finishes, this home features an open-concept layout, energy-efficient appliances, and a large backyard with a patio and garden. Ideal for first-time homebuyers or those looking to downsize.
#  Neighborhood Description: Green Meadows is a friendly, suburban community with excellent schools, parks, and recreational facilities. The neighborhood is known for its community events and strong sense of camaraderie among residents. Close to shopping centers and major highways.
#
#  **Personalized Property Description:**
#
# Welcome to your dream home in the heart of Green Meadows! This spacious 3-bedroom, 2-bathroom townhouse offers a perfect blend of comfort and practicality, ideal for family living. Featuring a beautifully finished basement, you'll find plenty of storage space to keep your home organized and clutter-free. The inviting open-concept layout is enhanced by modern finishes and energy-efficient appliances, making everyday living both stylish and sustainable. Step outside to your large backyard, where children can play safely while you enjoy the tranquility of your private patio and garden. With a convenient two-car garage, you'll have ample room for vehicles and outdoor gear.
#
# **Personalized Neighborhood Description:**
#
# Nestled in the vibrant and family-friendly community of Green Meadows, this townhouse is perfectly positioned for families seeking a nurturing environment. The neighborhood boasts excellent schools and a strong sense of community, with friendly neighbors and regular community events that foster camaraderie. Enjoy easy access to a nearby playground, perfect for your little ones to make friends and play. Commuting is a breeze with access to bus routes, major highways, and convenient carpooling options nearby, ensuring you can easily connect to the wider area. Experience the best of suburban living with a mix of tranquility and essential services, shopping centers, and recreational facilities just moments away. Welcome home!
#
# Listing 3
#
#  HomeMatch Score: 7
#  Internal listing id: 7
#
#  Original Listing:
#  Neighborhood: Riverstone Ridge
#  Price: $950,000
#  Bedrooms: 3
#  Bathrooms: 2.5
#  House Size: 2,300 sqft
#  Description: Contemporary 3-bedroom, 2.5-bathroom townhouse in Riverstone Ridge. This property offers a sleek design with an open-concept living area, high ceilings, and large windows. The rooftop terrace provides panoramic views of the river and the city.
#  Neighborhood Description: Riverstone Ridge is a trendy, up-and-coming neighborhood with a mix of modern living and natural beauty. Enjoy walking along the river, visiting local boutiques, and dining at hip cafes and restaurants. Excellent public transportation options make commuting easy.
#
#  ### Personalized Property Description
#
# Welcome to your new home in Riverstone Ridge! This contemporary 3-bedroom, 2.5-bathroom townhouse offers all the space and amenities your family desires. With approximately 2,300 sqft of thoughtfully designed living space, you’ll appreciate the finished basement perfect for play or storage, ensuring that there's room for everything your family needs. The open-concept living area is bathed in natural light from large windows, creating an inviting atmosphere, while the sleek design and high ceilings lend an air of modern sophistication.
#
# Your family will thrive in this family-friendly environment, where a playground for children is just around the corner, and energy-efficient appliances in your kitchen will help you save on utility bills. Enjoy the convenience of a two-car garage, making coming and going a breeze.
#
# ### Personalized Neighborhood Description
#
# Riverstone Ridge is not just a place to live; it's a vibrant community where families flourish. This suburban neighborhood strikes the perfect balance between tranquility and accessibility, with a focus on family-oriented amenities. Excellent schools nearby make it easy for your children to receive a quality education, while the sense of community here encourages connection and camaraderie among neighbors.
#
# Take leisurely strolls along the river or explore local boutiques and trendy cafes, all within reach. With easy access to major highways and bus routes, commuting is a stress-free experience, allowing you to fully enjoy everything this lovely neighborhood has to offer. Discover the perfect blend of modern living and natural beauty at Riverstone Ridge—your family’s new home awaits!
